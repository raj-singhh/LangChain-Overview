# %% [markdown]
# ### Agent With Memory

# %%
import os
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model=ChatGroq(model="qwen/qwen3-32b")

# %%
from langchain.agents import create_agent

from langgraph.checkpoint.memory import InMemorySaver

# %%
agent = create_agent(
    model = "groq:llama-3.3-70b-versatile",
    checkpointer = InMemorySaver()
    
)

# %%
### Run with thread id
config= {"configurable": {"thread_id": "thread_1"}}

# %%
from langchain_core.messages import HumanMessage, SystemMessage
response=agent.invoke({"messages":[HumanMessage(content="Hi my name is Raj")]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is Raj', additional_kwargs={}, response_metadata={}, id='ab0aa6de-60f6-48d8-a65f-8ba0abcd5cf6'),
#   AIMessage(content="Hello Raj, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 40, 'total_tokens': 66, 'completion_time': 0.038802785, 'completion_tokens_details': None, 'prompt_time': 0.006715755, 'prompt_tokens_details': None, 'queue_time': 0.160887735, 'total_time': 0.04551854}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cfa1f-a0a2-76f3-9625-e798d70dbe67-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 26, 'total_tokens': 66})]}

# %%
response=agent.invoke({"messages":[HumanMessage(content="What is my Name?")]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is Raj', additional_kwargs={}, response_metadata={}, id='ab0aa6de-60f6-48d8-a65f-8ba0abcd5cf6'),
#   AIMessage(content="Hello Raj, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 40, 'total_tokens': 66, 'completion_time': 0.038802785, 'completion_tokens_details': None, 'prompt_time': 0.006715755, 'prompt_tokens_details': None, 'queue_time': 0.160887735, 'total_time': 0.04551854}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cfa1f-a0a2-76f3-9625-e798d70dbe67-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 26, 'total_tokens': 66}),
# ...

# %%
### Run with thread id
config= {"configurable": {"thread_id": "thread_3"}}
from langchain_core.messages import HumanMessage, SystemMessage
response=agent.invoke({"messages":[HumanMessage(content="Hi my name is manoj")]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is manoj', additional_kwargs={}, response_metadata={}, id='6fb90c98-c7c0-4d5b-bde6-841ad553a90d'),
#   AIMessage(content="Hello Manoj, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 41, 'total_tokens': 68, 'completion_time': 0.043965168, 'completion_tokens_details': None, 'prompt_time': 0.001951258, 'prompt_tokens_details': None, 'queue_time': 0.050292652, 'total_time': 0.045916426}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cfa22-d800-78b0-8468-c9ec8d197fab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 27, 'total_tokens': 68})]}

# %%
response=agent.invoke({"messages":[HumanMessage(content="What is my Name?")]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is manoj', additional_kwargs={}, response_metadata={}, id='6fb90c98-c7c0-4d5b-bde6-841ad553a90d'),
#   AIMessage(content="Hello Manoj, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 41, 'total_tokens': 68, 'completion_time': 0.043965168, 'completion_tokens_details': None, 'prompt_time': 0.001951258, 'prompt_tokens_details': None, 'queue_time': 0.050292652, 'total_time': 0.045916426}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cfa22-d800-78b0-8468-c9ec8d197fab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 27, 'total_tokens': 68}),
# ...
